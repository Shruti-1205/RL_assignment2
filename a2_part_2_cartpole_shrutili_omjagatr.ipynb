# %%
import gymnasium as gym
import numpy as np
import random
import math
import time
from collections import deque
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt

# %%
env = gym.make("CartPole-v1")

# %%
class ReplayMemory:
    def __init__(self, capacity):
        self.buffer = deque(maxlen=capacity)
    def push(self, transition):
        self.buffer.append(transition)
    def sample(self, batch_size):
        return random.sample(self.buffer, batch_size)
    def __len__(self):
        return len(self.buffer)

class DQN(nn.Module):
    def __init__(self, input_dim=4, hidden1=24, hidden2=32, output_dim=2):
        super(DQN, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, hidden1),
            nn.ReLU(),
            nn.Linear(hidden1, hidden2),
            nn.ReLU(),
            nn.Linear(hidden2, output_dim)
        )

    def forward(self, x):
        return self.net(x)

class DQNAgent:
    def __init__(self, env, memory_capacity=5000, batch_size=128,
                 gamma=0.99, lr=0.0005, target_update=10,
                 epsilon_start=1.0, epsilon_end=0.001, epsilon_decay=0.995):
        self.env = env
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.batch_size = batch_size
        self.gamma = gamma
        self.lr = lr
        self.target_update = target_update
        self.epsilon = epsilon_start
        self.epsilon_end = epsilon_end
        self.epsilon_decay = epsilon_decay

        self.policy_net = DQN(output_dim=env.action_space.n).to(self.device)
        self.target_net = DQN(output_dim=env.action_space.n).to(self.device)
        self.target_net.load_state_dict(self.policy_net.state_dict())
        self.target_net.eval()

        self.optimizer = optim.Adam(self.policy_net.parameters(), lr=self.lr)
        self.memory = ReplayMemory(memory_capacity)
        self.steps_done = 0

    def select_action(self, state):
        if random.random() < self.epsilon:
            return self.env.action_space.sample()
        else:
            state_tensor = torch.tensor(state, dtype=torch.float32, device=self.device).unsqueeze(0)
            with torch.no_grad():
                return self.policy_net(state_tensor).argmax().item()

    def optimize_model(self):
        if len(self.memory) < self.batch_size:
            return

        batch = self.memory.sample(self.batch_size)
        states, actions, rewards, next_states, dones = zip(*batch)

        states = torch.tensor(states, dtype=torch.float32, device=self.device)
        actions = torch.tensor(actions, dtype=torch.int64, device=self.device).unsqueeze(1)
        rewards = torch.tensor(rewards, dtype=torch.float32, device=self.device).unsqueeze(1)
        next_states = torch.tensor(next_states, dtype=torch.float32, device=self.device)
        dones = torch.tensor(dones, dtype=torch.bool, device=self.device).unsqueeze(1)

        q_values = self.policy_net(states).gather(1, actions)

        with torch.no_grad():
            next_q_values = self.target_net(next_states).max(1)[0].unsqueeze(1)
            target_q = rewards + self.gamma * next_q_values * (~dones)

        loss = nn.functional.mse_loss(q_values, target_q)

        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

    def train(self, num_episodes=500, max_steps=500, model_save_path="a2_part_2_dqn_cartpole_shrutili_omjagatr.pth"):
        rewards_per_episode = []
        epsilon_per_episode = []
        best_avg = -float("inf")

        for episode in range(num_episodes):
            state, _ = self.env.reset()
            state = np.array(state, dtype=np.float32)
            total_reward = 0

            for step in range(max_steps):
                action = self.select_action(state)
                next_state, reward, terminated, truncated, _ = self.env.step(action)
                done = terminated or truncated
                next_state = np.array(next_state, dtype=np.float32)

                self.memory.push((state, action, reward, next_state, done))
                state = next_state
                total_reward += reward

                self.optimize_model()

                if done:
                    break

            rewards_per_episode.append(total_reward)
            self.epsilon = max(self.epsilon_end, self.epsilon * self.epsilon_decay)
            epsilon_per_episode.append(self.epsilon)

            if episode % self.target_update == 0:
                self.target_net.load_state_dict(self.policy_net.state_dict())

            avg_recent = np.mean(rewards_per_episode[-10:])
            if avg_recent > best_avg and avg_recent >= 480:
                best_avg = avg_recent
                self.save_model(model_save_path)
                print(f"Solved Environment: Episode {episode}, Avg Reward of last 10 episodes: {avg_recent:.2f}")
                break

            if episode % 10 == 0:
                print(f"Episode {episode}, Reward: {total_reward}, Epsilon: {self.epsilon:.3f}")

        return rewards_per_episode, epsilon_per_episode

    def save_model(self, filename="a2_part_2_dqn_cartpole_shrutili_omjagatr.pth"):
        torch.save(self.policy_net.state_dict(), filename)

    def load_model(self, filename="a2_part_2_dqn_cartpole_shrutili_omjagatr.pth"):
        self.policy_net.load_state_dict(torch.load(filename))
        self.target_net.load_state_dict(self.policy_net.state_dict())

# %%
agent = DQNAgent(env)
rewards, epsilons = agent.train(num_episodes=2000)
# Out:
# Episode 0, Reward: 26.0, Epsilon: 0.995
# <ipython-input-3-c37557d15ceb>:66: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /pytorch/torch/csrc/utils/tensor_new.cpp:254.)
#   states = torch.tensor(states, dtype=torch.float32, device=self.device)
# Episode 10, Reward: 60.0, Epsilon: 0.946
# Episode 20, Reward: 13.0, Epsilon: 0.900
# Episode 30, Reward: 57.0, Epsilon: 0.856
# Episode 40, Reward: 25.0, Epsilon: 0.814
# Episode 50, Reward: 31.0, Epsilon: 0.774
# Episode 60, Reward: 29.0, Epsilon: 0.737
# Episode 70, Reward: 9.0, Epsilon: 0.701
# Episode 80, Reward: 36.0, Epsilon: 0.666
# Episode 90, Reward: 32.0, Epsilon: 0.634
# Episode 100, Reward: 144.0, Epsilon: 0.603
# Episode 110, Reward: 124.0, Epsilon: 0.573
# Episode 120, Reward: 307.0, Epsilon: 0.545
# Episode 130, Reward: 197.0, Epsilon: 0.519
# Episode 140, Reward: 121.0, Epsilon: 0.493
# Episode 150, Reward: 293.0, Epsilon: 0.469
# Episode 160, Reward: 50.0, Epsilon: 0.446
# Episode 170, Reward: 287.0, Epsilon: 0.424
# Episode 180, Reward: 191.0, Epsilon: 0.404
# Episode 190, Reward: 284.0, Epsilon: 0.384
# Episode 200, Reward: 411.0, Epsilon: 0.365
# Episode 210, Reward: 238.0, Epsilon: 0.347
# Episode 220, Reward: 317.0, Epsilon: 0.330
# Episode 230, Reward: 192.0, Epsilon: 0.314
# Episode 240, Reward: 159.0, Epsilon: 0.299
# Episode 250, Reward: 151.0, Epsilon: 0.284
# Episode 260, Reward: 96.0, Epsilon: 0.270
# Episode 270, Reward: 145.0, Epsilon: 0.257
# Episode 280, Reward: 111.0, Epsilon: 0.245
# Episode 290, Reward: 115.0, Epsilon: 0.233
# Episode 300, Reward: 115.0, Epsilon: 0.221
# Episode 310, Reward: 109.0, Epsilon: 0.210
# Episode 320, Reward: 112.0, Epsilon: 0.200
# Episode 330, Reward: 107.0, Epsilon: 0.190
# Episode 340, Reward: 103.0, Epsilon: 0.181
# Episode 350, Reward: 108.0, Epsilon: 0.172
# Episode 360, Reward: 102.0, Epsilon: 0.164
# Episode 370, Reward: 213.0, Epsilon: 0.156
# Episode 380, Reward: 62.0, Epsilon: 0.148
# Episode 390, Reward: 164.0, Epsilon: 0.141
# Episode 400, Reward: 403.0, Epsilon: 0.134
# Episode 410, Reward: 197.0, Epsilon: 0.127
# Episode 420, Reward: 265.0, Epsilon: 0.121
# Episode 430, Reward: 152.0, Epsilon: 0.115
# Episode 440, Reward: 152.0, Epsilon: 0.110
# Episode 450, Reward: 158.0, Epsilon: 0.104
# Episode 460, Reward: 156.0, Epsilon: 0.099
# Episode 470, Reward: 158.0, Epsilon: 0.094
# Episode 480, Reward: 118.0, Epsilon: 0.090
# Episode 490, Reward: 114.0, Epsilon: 0.085
# Episode 500, Reward: 103.0, Epsilon: 0.081
# Episode 510, Reward: 97.0, Epsilon: 0.077
# Episode 520, Reward: 58.0, Epsilon: 0.073
# Episode 530, Reward: 98.0, Epsilon: 0.070
# Episode 540, Reward: 98.0, Epsilon: 0.066
# Episode 550, Reward: 116.0, Epsilon: 0.063
# Episode 560, Reward: 28.0, Epsilon: 0.060
# Episode 570, Reward: 103.0, Epsilon: 0.057
# Episode 580, Reward: 103.0, Epsilon: 0.054
# Episode 590, Reward: 93.0, Epsilon: 0.052
# Episode 600, Reward: 56.0, Epsilon: 0.049
# Episode 610, Reward: 92.0, Epsilon: 0.047
# Episode 620, Reward: 98.0, Epsilon: 0.044
# Episode 630, Reward: 93.0, Epsilon: 0.042
# Episode 640, Reward: 95.0, Epsilon: 0.040
# Episode 650, Reward: 94.0, Epsilon: 0.038
# Episode 660, Reward: 91.0, Epsilon: 0.036
# Episode 670, Reward: 102.0, Epsilon: 0.035
# Episode 680, Reward: 107.0, Epsilon: 0.033
# Episode 690, Reward: 374.0, Epsilon: 0.031
# Episode 700, Reward: 144.0, Epsilon: 0.030
# Episode 710, Reward: 187.0, Epsilon: 0.028
# Episode 720, Reward: 183.0, Epsilon: 0.027
# Episode 730, Reward: 208.0, Epsilon: 0.026
# Episode 740, Reward: 172.0, Epsilon: 0.024
# Episode 750, Reward: 127.0, Epsilon: 0.023
# Episode 760, Reward: 147.0, Epsilon: 0.022
# Episode 770, Reward: 168.0, Epsilon: 0.021
# Episode 780, Reward: 150.0, Epsilon: 0.020
# Episode 790, Reward: 173.0, Epsilon: 0.019
# Episode 800, Reward: 219.0, Epsilon: 0.018
# Episode 810, Reward: 110.0, Epsilon: 0.017
# Episode 820, Reward: 76.0, Epsilon: 0.016
# Episode 830, Reward: 103.0, Epsilon: 0.016
# Episode 840, Reward: 105.0, Epsilon: 0.015
# Episode 850, Reward: 174.0, Epsilon: 0.014
# Episode 860, Reward: 183.0, Epsilon: 0.013
# Episode 870, Reward: 178.0, Epsilon: 0.013
# Episode 880, Reward: 141.0, Epsilon: 0.012
# Episode 890, Reward: 146.0, Epsilon: 0.011
# Episode 900, Reward: 138.0, Epsilon: 0.011
# Episode 910, Reward: 135.0, Epsilon: 0.010
# Episode 920, Reward: 165.0, Epsilon: 0.010
# Episode 930, Reward: 288.0, Epsilon: 0.009
# Episode 940, Reward: 146.0, Epsilon: 0.009
# Episode 950, Reward: 143.0, Epsilon: 0.009
# Episode 960, Reward: 152.0, Epsilon: 0.008
# Episode 970, Reward: 164.0, Epsilon: 0.008
# Episode 980, Reward: 182.0, Epsilon: 0.007
# Episode 990, Reward: 185.0, Epsilon: 0.007
# Episode 1000, Reward: 179.0, Epsilon: 0.007
# Episode 1010, Reward: 234.0, Epsilon: 0.006
# Episode 1020, Reward: 423.0, Epsilon: 0.006
# Episode 1030, Reward: 478.0, Epsilon: 0.006
# Episode 1040, Reward: 216.0, Epsilon: 0.005
# Episode 1050, Reward: 500.0, Epsilon: 0.005
# Solved Environment: Episode 1058, Avg Reward of last 10 episodes: 485.90

# %% [markdown]
# > Epsilon Decay Graph

# %%
plt.plot(epsilons)
plt.xlabel("Episode")
plt.ylabel("Epsilon (Exploration Rate)")
plt.title("Epsilon Decay Over Episodes")
plt.grid(True)
plt.show()

# %% [markdown]
# > Total Rewards per Epsiode

# %%
plt.plot(rewards)
plt.xlabel("Episode")
plt.ylabel("Total Reward")
plt.title("Training Rewards")
plt.grid(True)
plt.show()

# %% [markdown]
# > Running the agent for 10 episodes, where
# the agent chooses only greedy actions from the learnt policy.

# %%
agent.load_model("a2_part_2_gridworld_shrutili_omjagatr")
eval_rewards = []
print("Greedy Policy Evaluation")
for episode in range(10):
    state, _ = env.reset()
    total_reward = 0
    done = False
    while not done:
        state_tensor = torch.tensor(state, dtype=torch.float32).unsqueeze(0).to(agent.device)
        with torch.no_grad():
            action = agent.policy_net(state_tensor).argmax().item()
        next_state, reward, terminated, truncated, _ = env.step(action)
        state = next_state
        total_reward += reward
        done = terminated or truncated
    eval_rewards.append(total_reward)
    print(f"Episode {episode+1}, Total Reward: {total_reward}")
# Out:
# Greedy Policy Evaluation
# Episode 1, Total Reward: 500.0
# Episode 2, Total Reward: 500.0
# Episode 3, Total Reward: 500.0
# Episode 4, Total Reward: 500.0
# Episode 5, Total Reward: 500.0
# Episode 6, Total Reward: 500.0
# Episode 7, Total Reward: 500.0
# Episode 8, Total Reward: 500.0
# Episode 9, Total Reward: 500.0
# Episode 10, Total Reward: 500.0

# %% [markdown]
# > Total Reward per Episode for Evaluation

# %%
plt.plot(eval_rewards)
plt.xlabel("Episode")
plt.ylabel("Total Reward")
plt.title("Evaluation Reward per Episode")
plt.grid(True)
plt.show()

# %% [markdown]
# > 1 episode where the agent chooses only
# greedy actions from the learned policy

# %%
agent.load_model("a2_part_2_dqn_cartpole_shrutili_omjagatr.pth")
state, _ = env.reset()
state = np.array(state, dtype=np.float32)
done = False
total_reward = 0
step = 0
while not done:
    state_tensor = torch.tensor(state, dtype=torch.float32).unsqueeze(0).to(agent.device)
    with torch.no_grad():
        action = agent.policy_net(state_tensor).argmax().item()
    next_state, reward, terminated, truncated, _ = env.step(action)
    next_state = np.array(next_state, dtype=np.float32)

    print(f"Step {step}: State = {np.round(state, 3)}, Action = {action}, Reward = {reward}")
    state = next_state
    total_reward += reward
    done = terminated or truncated
    step += 1
env.close()
print(f"\nGreedy Episode Total Reward: {total_reward}")
# Out:
# Step 0: State = [0.04  0.047 0.012 0.026], Action = 1, Reward = 1.0
# Step 1: State = [ 0.041  0.242  0.013 -0.263], Action = 1, Reward = 1.0
# Step 2: State = [ 0.046  0.437  0.007 -0.551], Action = 1, Reward = 1.0
# Step 3: State = [ 0.054  0.632 -0.004 -0.842], Action = 1, Reward = 1.0
# Step 4: State = [ 0.067  0.827 -0.02  -1.136], Action = 1, Reward = 1.0
# Step 5: State = [ 0.083  1.022 -0.043 -1.435], Action = 0, Reward = 1.0
# Step 6: State = [ 0.104  0.828 -0.072 -1.156], Action = 0, Reward = 1.0
# Step 7: State = [ 0.12   0.634 -0.095 -0.886], Action = 0, Reward = 1.0
# Step 8: State = [ 0.133  0.44  -0.113 -0.625], Action = 0, Reward = 1.0
# Step 9: State = [ 0.142  0.247 -0.125 -0.37 ], Action = 0, Reward = 1.0
# Step 10: State = [ 0.147  0.053 -0.133 -0.119], Action = 1, Reward = 1.0
# Step 11: State = [ 0.148  0.25  -0.135 -0.451], Action = 0, Reward = 1.0
# Step 12: State = [ 0.153  0.057 -0.144 -0.203], Action = 0, Reward = 1.0
# Step 13: State = [ 0.154 -0.136 -0.148  0.041], Action = 0, Reward = 1.0
# Step 14: State = [ 0.151 -0.328 -0.147  0.283], Action = 0, Reward = 1.0
# Step 15: State = [ 0.145 -0.521 -0.142  0.526], Action = 0, Reward = 1.0
# Step 16: State = [ 0.134 -0.714 -0.131  0.771], Action = 0, Reward = 1.0
# Step 17: State = [ 0.12  -0.907 -0.116  1.02 ], Action = 0, Reward = 1.0
# Step 18: State = [ 0.102 -1.1   -0.095  1.274], Action = 0, Reward = 1.0
# Step 19: State = [ 0.08  -1.294 -0.07   1.536], Action = 1, Reward = 1.0
# Step 20: State = [ 0.054 -1.098 -0.039  1.222], Action = 1, Reward = 1.0
# Step 21: State = [ 0.032 -0.903 -0.015  0.917], Action = 1, Reward = 1.0
# Step 22: State = [ 0.014 -0.707  0.004  0.62 ], Action = 1, Reward = 1.0
# Step 23: State = [-0.    -0.512  0.016  0.329], Action = 1, Reward = 1.0
# Step 24: State = [-0.01  -0.317  0.023  0.041], Action = 1, Reward = 1.0
# Step 25: State = [-0.017 -0.123  0.024 -0.244], Action = 1, Reward = 1.0
# Step 26: State = [-0.019  0.072  0.019 -0.53 ], Action = 1, Reward = 1.0
# Step 27: State = [-0.018  0.267  0.008 -0.816], Action = 1, Reward = 1.0
# Step 28: State = [-0.012  0.462 -0.008 -1.107], Action = 0, Reward = 1.0
# Step 29: State = [-0.003  0.267 -0.03  -0.816], Action = 0, Reward = 1.0
# Step 30: State = [ 0.002  0.072 -0.047 -0.533], Action = 0, Reward = 1.0
# Step 31: State = [ 0.004 -0.122 -0.057 -0.256], Action = 0, Reward = 1.0
# Step 32: State = [ 0.001 -0.316 -0.063  0.018], Action = 0, Reward = 1.0
# Step 33: State = [-0.005 -0.511 -0.062  0.291], Action = 0, Reward = 1.0
# Step 34: State = [-0.015 -0.705 -0.056  0.563], Action = 0, Reward = 1.0
# Step 35: State = [-0.029 -0.899 -0.045  0.837], Action = 0, Reward = 1.0
# Step 36: State = [-0.047 -1.094 -0.028  1.116], Action = 1, Reward = 1.0
# Step 37: State = [-0.069 -0.898 -0.006  0.814], Action = 0, Reward = 1.0
# Step 38: State = [-0.087 -1.093  0.01   1.105], Action = 1, Reward = 1.0
# Step 39: State = [-0.109 -0.898  0.032  0.815], Action = 1, Reward = 1.0
# Step 40: State = [-0.127 -0.703  0.049  0.533], Action = 1, Reward = 1.0
# Step 41: State = [-0.141 -0.509  0.059  0.256], Action = 1, Reward = 1.0
# Step 42: State = [-0.151 -0.315  0.064 -0.017], Action = 1, Reward = 1.0
# Step 43: State = [-0.158 -0.121  0.064 -0.289], Action = 1, Reward = 1.0
# Step 44: State = [-0.16   0.073  0.058 -0.561], Action = 1, Reward = 1.0
# Step 45: State = [-0.159  0.268  0.047 -0.834], Action = 1, Reward = 1.0
# Step 46: State = [-0.153  0.462  0.03  -1.112], Action = 0, Reward = 1.0
# Step 47: State = [-0.144  0.267  0.008 -0.81 ], Action = 0, Reward = 1.0
# Step 48: State = [-0.139  0.071 -0.008 -0.515], Action = 0, Reward = 1.0
# Step 49: State = [-0.137 -0.124 -0.018 -0.224], Action = 0, Reward = 1.0
# Step 50: State = [-0.14  -0.318 -0.023  0.062], Action = 0, Reward = 1.0
# Step 51: State = [-0.146 -0.513 -0.022  0.348], Action = 0, Reward = 1.0
# Step 52: State = [-0.156 -0.708 -0.015  0.634], Action = 0, Reward = 1.0
# Step 53: State = [-0.17  -0.903 -0.002  0.922], Action = 1, Reward = 1.0
# Step 54: State = [-0.189 -0.708  0.017  0.628], Action = 1, Reward = 1.0
# Step 55: State = [-0.203 -0.513  0.029  0.341], Action = 1, Reward = 1.0
# Step 56: State = [-0.213 -0.318  0.036  0.058], Action = 1, Reward = 1.0
# Step 57: State = [-0.219 -0.124  0.037 -0.224], Action = 1, Reward = 1.0
# Step 58: State = [-0.222  0.071  0.033 -0.504], Action = 0, Reward = 1.0
# Step 59: State = [-0.22  -0.125  0.022 -0.202], Action = 0, Reward = 1.0
# Step 60: State = [-0.223 -0.32   0.018  0.098], Action = 0, Reward = 1.0
# Step 61: State = [-0.229 -0.515  0.02   0.397], Action = 1, Reward = 1.0
# Step 62: State = [-0.24  -0.321  0.028  0.11 ], Action = 1, Reward = 1.0
# Step 63: State = [-0.246 -0.126  0.031 -0.173], Action = 1, Reward = 1.0
# Step 64: State = [-0.249  0.069  0.027 -0.456], Action = 0, Reward = 1.0
# Step 65: State = [-0.247 -0.127  0.018 -0.155], Action = 0, Reward = 1.0
# Step 66: State = [-0.25  -0.322  0.015  0.143], Action = 0, Reward = 1.0
# Step 67: State = [-0.256 -0.517  0.018  0.441], Action = 1, Reward = 1.0
# Step 68: State = [-0.266 -0.323  0.027  0.154], Action = 1, Reward = 1.0
# Step 69: State = [-0.273 -0.128  0.03  -0.131], Action = 1, Reward = 1.0
# Step 70: State = [-0.275  0.067  0.027 -0.414], Action = 0, Reward = 1.0
# Step 71: State = [-0.274 -0.129  0.019 -0.113], Action = 0, Reward = 1.0
# Step 72: State = [-0.277 -0.324  0.016  0.186], Action = 0, Reward = 1.0
# Step 73: State = [-0.283 -0.519  0.02   0.484], Action = 1, Reward = 1.0
# Step 74: State = [-0.294 -0.325  0.03   0.197], Action = 1, Reward = 1.0
# Step 75: State = [-0.3   -0.13   0.034 -0.086], Action = 1, Reward = 1.0
# Step 76: State = [-0.303  0.065  0.032 -0.368], Action = 1, Reward = 1.0
# Step 77: State = [-0.301  0.259  0.025 -0.65 ], Action = 0, Reward = 1.0
# Step 78: State = [-0.296  0.064  0.012 -0.35 ], Action = 0, Reward = 1.0
# Step 79: State = [-0.295 -0.131  0.005 -0.053], Action = 0, Reward = 1.0
# Step 80: State = [-0.298 -0.327  0.004  0.241], Action = 0, Reward = 1.0
# Step 81: State = [-0.304 -0.522  0.009  0.535], Action = 1, Reward = 1.0
# Step 82: State = [-0.314 -0.327  0.019  0.245], Action = 1, Reward = 1.0
# Step 83: State = [-0.321 -0.132  0.024 -0.042], Action = 1, Reward = 1.0
# Step 84: State = [-0.324  0.063  0.023 -0.327], Action = 0, Reward = 1.0
# Step 85: State = [-0.322 -0.133  0.017 -0.027], Action = 0, Reward = 1.0
# Step 86: State = [-0.325 -0.328  0.016  0.271], Action = 1, Reward = 1.0
# Step 87: State = [-0.332 -0.133  0.022 -0.016], Action = 1, Reward = 1.0
# Step 88: State = [-0.334  0.062  0.021 -0.302], Action = 0, Reward = 1.0
# Step 89: State = [-0.333 -0.134  0.015 -0.003], Action = 0, Reward = 1.0
# Step 90: State = [-0.336 -0.329  0.015  0.295], Action = 1, Reward = 1.0
# Step 91: State = [-0.342 -0.134  0.021  0.007], Action = 1, Reward = 1.0
# Step 92: State = [-0.345  0.061  0.021 -0.279], Action = 1, Reward = 1.0
# Step 93: State = [-0.344  0.256  0.016 -0.565], Action = 0, Reward = 1.0
# Step 94: State = [-0.339  0.06   0.004 -0.268], Action = 0, Reward = 1.0
# Step 95: State = [-0.337 -0.135 -0.001  0.026], Action = 0, Reward = 1.0
# Step 96: State = [-0.34  -0.33  -0.     0.319], Action = 0, Reward = 1.0
# Step 97: State = [-0.347 -0.525  0.006  0.611], Action = 1, Reward = 1.0
# Step 98: State = [-0.357 -0.33   0.018  0.321], Action = 1, Reward = 1.0
# Step 99: State = [-0.364 -0.135  0.025  0.034], Action = 1, Reward = 1.0
# Step 100: State = [-0.367  0.059  0.025 -0.251], Action = 1, Reward = 1.0
# Step 101: State = [-0.365  0.254  0.02  -0.536], Action = 0, Reward = 1.0
# Step 102: State = [-0.36   0.059  0.009 -0.237], Action = 0, Reward = 1.0
# Step 103: State = [-0.359 -0.136  0.005  0.059], Action = 0, Reward = 1.0
# Step 104: State = [-0.362 -0.332  0.006  0.353], Action = 1, Reward = 1.0
# Step 105: State = [-0.368 -0.137  0.013  0.062], Action = 1, Reward = 1.0
# Step 106: State = [-0.371  0.058  0.014 -0.226], Action = 0, Reward = 1.0
# Step 107: State = [-0.37  -0.137  0.01   0.071], Action = 0, Reward = 1.0
# Step 108: State = [-0.373 -0.332  0.011  0.366], Action = 1, Reward = 1.0
# Step 109: State = [-0.379 -0.137  0.018  0.077], Action = 1, Reward = 1.0
# Step 110: State = [-0.382  0.058  0.02  -0.21 ], Action = 1, Reward = 1.0
# Step 111: State = [-0.381  0.252  0.016 -0.496], Action = 0, Reward = 1.0
# Step 112: State = [-0.376  0.057  0.006 -0.198], Action = 0, Reward = 1.0
# Step 113: State = [-0.375 -0.138  0.002  0.096], Action = 0, Reward = 1.0
# Step 114: State = [-0.378 -0.333  0.004  0.39 ], Action = 1, Reward = 1.0
# Step 115: State = [-0.384 -0.138  0.012  0.098], Action = 1, Reward = 1.0
# Step 116: State = [-0.387  0.057  0.014 -0.191], Action = 1, Reward = 1.0
# Step 117: State = [-0.386  0.252  0.01  -0.479], Action = 0, Reward = 1.0
# Step 118: State = [-0.381  0.056  0.    -0.184], Action = 0, Reward = 1.0
# Step 119: State = [-0.38  -0.139 -0.004  0.109], Action = 0, Reward = 1.0
# Step 120: State = [-0.382 -0.334 -0.001  0.401], Action = 0, Reward = 1.0
# Step 121: State = [-0.389 -0.529  0.007  0.693], Action = 1, Reward = 1.0
# Step 122: State = [-0.4   -0.334  0.021  0.402], Action = 1, Reward = 1.0
# Step 123: State = [-0.406 -0.139  0.029  0.116], Action = 1, Reward = 1.0
# Step 124: State = [-0.409  0.056  0.031 -0.167], Action = 1, Reward = 1.0
# Step 125: State = [-0.408  0.25   0.028 -0.45 ], Action = 1, Reward = 1.0
# Step 126: State = [-0.403  0.445  0.019 -0.734], Action = 0, Reward = 1.0
# Step 127: State = [-0.394  0.25   0.004 -0.435], Action = 0, Reward = 1.0
# Step 128: State = [-0.389  0.055 -0.005 -0.142], Action = 0, Reward = 1.0
# Step 129: State = [-0.388 -0.141 -0.008  0.15 ], Action = 0, Reward = 1.0
# Step 130: State = [-0.391 -0.336 -0.005  0.44 ], Action = 0, Reward = 1.0
# Step 131: State = [-0.398 -0.531  0.004  0.731], Action = 1, Reward = 1.0
# Step 132: State = [-0.408 -0.336  0.019  0.44 ], Action = 1, Reward = 1.0
# Step 133: State = [-0.415 -0.141  0.028  0.153], Action = 1, Reward = 1.0
# Step 134: State = [-0.418  0.054  0.031 -0.131], Action = 1, Reward = 1.0
# Step 135: State = [-0.417  0.249  0.028 -0.414], Action = 1, Reward = 1.0
# Step 136: State = [-0.412  0.443  0.02  -0.697], Action = 1, Reward = 1.0
# Step 137: State = [-0.403  0.638  0.006 -0.984], Action = 0, Reward = 1.0
# Step 138: State = [-0.39   0.443 -0.014 -0.689], Action = 0, Reward = 1.0
# Step 139: State = [-0.381  0.248 -0.028 -0.401], Action = 0, Reward = 1.0
# Step 140: State = [-0.376  0.053 -0.036 -0.117], Action = 0, Reward = 1.0
# Step 141: State = [-0.375 -0.141 -0.038  0.164], Action = 0, Reward = 1.0
# Step 142: State = [-0.378 -0.336 -0.035  0.444], Action = 0, Reward = 1.0
# Step 143: State = [-0.385 -0.53  -0.026  0.726], Action = 0, Reward = 1.0
# Step 144: State = [-0.395 -0.725 -0.011  1.01 ], Action = 1, Reward = 1.0
# Step 145: State = [-0.41  -0.53   0.009  0.714], Action = 1, Reward = 1.0
# Step 146: State = [-0.42  -0.335  0.023  0.424], Action = 1, Reward = 1.0
# Step 147: State = [-0.427 -0.14   0.032  0.139], Action = 1, Reward = 1.0
# Step 148: State = [-0.43   0.055  0.034 -0.144], Action = 1, Reward = 1.0
# Step 149: State = [-0.429  0.249  0.031 -0.425], Action = 1, Reward = 1.0
# Step 150: State = [-0.424  0.444  0.023 -0.708], Action = 1, Reward = 1.0
# Step 151: State = [-0.415  0.639  0.009 -0.993], Action = 0, Reward = 1.0
# Step 152: State = [-0.402  0.443 -0.011 -0.698], Action = 0, Reward = 1.0
# Step 153: State = [-0.393  0.248 -0.025 -0.409], Action = 0, Reward = 1.0
# Step 154: State = [-0.388  0.054 -0.033 -0.124], Action = 0, Reward = 1.0
# Step 155: State = [-0.387 -0.141 -0.036  0.158], Action = 0, Reward = 1.0
# Step 156: State = [-0.39  -0.336 -0.033  0.439], Action = 0, Reward = 1.0
# Step 157: State = [-0.397 -0.53  -0.024  0.721], Action = 0, Reward = 1.0
# Step 158: State = [-0.407 -0.725 -0.009  1.007], Action = 1, Reward = 1.0
# Step 159: State = [-0.422 -0.53   0.011  0.711], Action = 1, Reward = 1.0
# Step 160: State = [-0.432 -0.335  0.025  0.422], Action = 1, Reward = 1.0
# Step 161: State = [-0.439 -0.14   0.033  0.137], Action = 1, Reward = 1.0
# Step 162: State = [-0.442  0.055  0.036 -0.145], Action = 1, Reward = 1.0
# Step 163: State = [-0.441  0.249  0.033 -0.426], Action = 1, Reward = 1.0
# Step 164: State = [-0.436  0.444  0.025 -0.708], Action = 1, Reward = 1.0
# Step 165: State = [-0.427  0.639  0.011 -0.993], Action = 0, Reward = 1.0
# Step 166: State = [-0.414  0.443 -0.009 -0.697], Action = 0, Reward = 1.0
# Step 167: State = [-0.405  0.248 -0.023 -0.407], Action = 0, Reward = 1.0
# Step 168: State = [-0.4    0.054 -0.031 -0.122], Action = 0, Reward = 1.0
# Step 169: State = [-0.399 -0.141 -0.034  0.161], Action = 0, Reward = 1.0
# Step 170: State = [-0.402 -0.336 -0.03   0.443], Action = 0, Reward = 1.0
# Step 171: State = [-0.409 -0.53  -0.022  0.726], Action = 0, Reward = 1.0
# Step 172: State = [-0.419 -0.725 -0.007  1.012], Action = 1, Reward = 1.0
# Step 173: State = [-0.434 -0.53   0.013  0.717], Action = 1, Reward = 1.0
# Step 174: State = [-0.445 -0.335  0.027  0.428], Action = 1, Reward = 1.0
# Step 175: State = [-0.451 -0.14   0.036  0.144], Action = 1, Reward = 1.0
# Step 176: State = [-0.454  0.054  0.039 -0.137], Action = 1, Reward = 1.0
# Step 177: State = [-0.453  0.249  0.036 -0.417], Action = 1, Reward = 1.0
# Step 178: State = [-0.448  0.443  0.028 -0.698], Action = 1, Reward = 1.0
# Step 179: State = [-0.439  0.638  0.014 -0.982], Action = 0, Reward = 1.0
# Step 180: State = [-0.426  0.443 -0.006 -0.685], Action = 0, Reward = 1.0
# Step 181: State = [-0.418  0.248 -0.019 -0.394], Action = 0, Reward = 1.0
# Step 182: State = [-0.413  0.053 -0.027 -0.107], Action = 0, Reward = 1.0
# Step 183: State = [-0.412 -0.142 -0.029  0.176], Action = 0, Reward = 1.0
# Step 184: State = [-0.414 -0.336 -0.026  0.46 ], Action = 0, Reward = 1.0
# Step 185: State = [-0.421 -0.531 -0.017  0.744], Action = 1, Reward = 1.0
# Step 186: State = [-0.432 -0.336 -0.002  0.446], Action = 0, Reward = 1.0
# Step 187: State = [-0.438 -0.531  0.007  0.738], Action = 1, Reward = 1.0
# Step 188: State = [-0.449 -0.336  0.022  0.448], Action = 1, Reward = 1.0
# Step 189: State = [-0.456 -0.141  0.031  0.162], Action = 1, Reward = 1.0
# Step 190: State = [-0.459  0.054  0.034 -0.121], Action = 1, Reward = 1.0
# Step 191: State = [-0.458  0.248  0.032 -0.403], Action = 1, Reward = 1.0
# Step 192: State = [-0.453  0.443  0.024 -0.685], Action = 1, Reward = 1.0
# Step 193: State = [-0.444  0.638  0.01  -0.97 ], Action = 0, Reward = 1.0
# Step 194: State = [-0.431  0.442 -0.01  -0.675], Action = 0, Reward = 1.0
# Step 195: State = [-0.422  0.247 -0.023 -0.385], Action = 0, Reward = 1.0
# Step 196: State = [-0.417  0.053 -0.031 -0.1  ], Action = 0, Reward = 1.0
# Step 197: State = [-0.416 -0.142 -0.033  0.183], Action = 0, Reward = 1.0
# Step 198: State = [-0.419 -0.337 -0.029  0.465], Action = 0, Reward = 1.0
# Step 199: State = [-0.426 -0.531 -0.02   0.749], Action = 0, Reward = 1.0
# Step 200: State = [-0.436 -0.726 -0.005  1.035], Action = 1, Reward = 1.0
# Step 201: State = [-0.451 -0.531  0.016  0.741], Action = 1, Reward = 1.0
# Step 202: State = [-0.461 -0.336  0.031  0.453], Action = 1, Reward = 1.0
# Step 203: State = [-0.468 -0.141  0.04   0.17 ], Action = 1, Reward = 1.0
# Step 204: State = [-0.471  0.053  0.043 -0.109], Action = 1, Reward = 1.0
# Step 205: State = [-0.47   0.248  0.041 -0.388], Action = 1, Reward = 1.0
# Step 206: State = [-0.465  0.442  0.033 -0.668], Action = 1, Reward = 1.0
# Step 207: State = [-0.456  0.637  0.02  -0.95 ], Action = 0, Reward = 1.0
# Step 208: State = [-0.443  0.441  0.001 -0.651], Action = 0, Reward = 1.0
# Step 209: State = [-0.435  0.246 -0.012 -0.358], Action = 0, Reward = 1.0
# Step 210: State = [-0.43   0.051 -0.019 -0.069], Action = 0, Reward = 1.0
# Step 211: State = [-0.429 -0.144 -0.021  0.218], Action = 0, Reward = 1.0
# Step 212: State = [-0.432 -0.338 -0.016  0.504], Action = 0, Reward = 1.0
# Step 213: State = [-0.438 -0.533 -0.006  0.791], Action = 1, Reward = 1.0
# Step 214: State = [-0.449 -0.338  0.01   0.496], Action = 1, Reward = 1.0
# Step 215: State = [-0.456 -0.143  0.02   0.207], Action = 1, Reward = 1.0
# Step 216: State = [-0.459  0.052  0.024 -0.08 ], Action = 1, Reward = 1.0
# Step 217: State = [-0.458  0.246  0.022 -0.365], Action = 1, Reward = 1.0
# Step 218: State = [-0.453  0.441  0.015 -0.65 ], Action = 0, Reward = 1.0
# Step 219: State = [-0.444  0.246  0.002 -0.353], Action = 0, Reward = 1.0
# Step 220: State = [-0.439  0.051 -0.005 -0.06 ], Action = 0, Reward = 1.0
# Step 221: State = [-0.438 -0.144 -0.007  0.231], Action = 0, Reward = 1.0
# Step 222: State = [-0.441 -0.339 -0.002  0.522], Action = 1, Reward = 1.0
# Step 223: State = [-0.448 -0.144  0.009  0.228], Action = 1, Reward = 1.0
# Step 224: State = [-0.45   0.051  0.013 -0.061], Action = 1, Reward = 1.0
# Step 225: State = [-0.449  0.246  0.012 -0.35 ], Action = 1, Reward = 1.0
# Step 226: State = [-0.444  0.441  0.005 -0.639], Action = 0, Reward = 1.0
# Step 227: State = [-0.436  0.246 -0.008 -0.345], Action = 0, Reward = 1.0
# Step 228: State = [-0.431  0.051 -0.015 -0.054], Action = 0, Reward = 1.0
# Step 229: State = [-0.43  -0.144 -0.016  0.233], Action = 0, Reward = 1.0
# Step 230: State = [-0.433 -0.339 -0.011  0.521], Action = 0, Reward = 1.0
# Step 231: State = [-0.439 -0.534 -0.001  0.81 ], Action = 1, Reward = 1.0
# Step 232: State = [-0.45  -0.339  0.015  0.517], Action = 1, Reward = 1.0
# Step 233: State = [-0.457 -0.144  0.026  0.23 ], Action = 1, Reward = 1.0
# Step 234: State = [-0.46   0.051  0.03  -0.055], Action = 1, Reward = 1.0
# Step 235: State = [-0.459  0.245  0.029 -0.338], Action = 1, Reward = 1.0
# Step 236: State = [-0.454  0.44   0.023 -0.621], Action = 1, Reward = 1.0
# Step 237: State = [-0.445  0.635  0.01  -0.907], Action = 0, Reward = 1.0
# Step 238: State = [-0.432  0.439 -0.008 -0.611], Action = 0, Reward = 1.0
# Step 239: State = [-0.424  0.244 -0.02  -0.321], Action = 0, Reward = 1.0
# Step 240: State = [-0.419  0.05  -0.027 -0.034], Action = 0, Reward = 1.0
# Step 241: State = [-0.418 -0.145 -0.027  0.25 ], Action = 0, Reward = 1.0
# Step 242: State = [-0.421 -0.34  -0.022  0.534], Action = 0, Reward = 1.0
# Step 243: State = [-0.427 -0.535 -0.012  0.819], Action = 1, Reward = 1.0
# Step 244: State = [-0.438 -0.339  0.005  0.523], Action = 1, Reward = 1.0
# Step 245: State = [-0.445 -0.144  0.015  0.232], Action = 1, Reward = 1.0
# Step 246: State = [-0.448  0.051  0.02  -0.056], Action = 1, Reward = 1.0
# Step 247: State = [-0.447  0.245  0.019 -0.343], Action = 1, Reward = 1.0
# Step 248: State = [-0.442  0.44   0.012 -0.629], Action = 1, Reward = 1.0
# Step 249: State = [-0.433  0.635 -0.001 -0.918], Action = 0, Reward = 1.0
# Step 250: State = [-0.42   0.44  -0.019 -0.626], Action = 0, Reward = 1.0
# Step 251: State = [-0.412  0.245 -0.032 -0.339], Action = 0, Reward = 1.0
# Step 252: State = [-0.407  0.051 -0.038 -0.057], Action = 0, Reward = 1.0
# Step 253: State = [-0.406 -0.144 -0.04   0.224], Action = 0, Reward = 1.0
# Step 254: State = [-0.408 -0.338 -0.035  0.504], Action = 0, Reward = 1.0
# Step 255: State = [-0.415 -0.533 -0.025  0.785], Action = 0, Reward = 1.0
# Step 256: State = [-0.426 -0.728 -0.009  1.07 ], Action = 1, Reward = 1.0
# Step 257: State = [-0.44  -0.533  0.012  0.774], Action = 1, Reward = 1.0
# Step 258: State = [-0.451 -0.338  0.028  0.485], Action = 1, Reward = 1.0
# Step 259: State = [-0.458 -0.143  0.037  0.201], Action = 1, Reward = 1.0
# Step 260: State = [-0.461  0.052  0.041 -0.079], Action = 1, Reward = 1.0
# Step 261: State = [-0.46   0.246  0.04  -0.359], Action = 1, Reward = 1.0
# Step 262: State = [-0.455  0.441  0.033 -0.639], Action = 1, Reward = 1.0
# Step 263: State = [-0.446  0.635  0.02  -0.921], Action = 1, Reward = 1.0
# Step 264: State = [-4.330e-01  8.300e-01  1.000e-03 -1.207e+00], Action = 0, Reward = 1.0
# Step 265: State = [-0.417  0.635 -0.023 -0.914], Action = 0, Reward = 1.0
# Step 266: State = [-0.404  0.44  -0.041 -0.629], Action = 0, Reward = 1.0
# Step 267: State = [-0.395  0.246 -0.054 -0.349], Action = 0, Reward = 1.0
# Step 268: State = [-0.39   0.051 -0.061 -0.074], Action = 0, Reward = 1.0
# Step 269: State = [-0.389 -0.143 -0.062  0.199], Action = 0, Reward = 1.0
# Step 270: State = [-0.392 -0.337 -0.058  0.471], Action = 0, Reward = 1.0
# Step 271: State = [-0.399 -0.531 -0.049  0.745], Action = 0, Reward = 1.0
# Step 272: State = [-0.409 -0.726 -0.034  1.022], Action = 1, Reward = 1.0
# Step 273: State = [-0.424 -0.53  -0.013  0.719], Action = 1, Reward = 1.0
# Step 274: State = [-0.434 -0.335  0.001  0.422], Action = 0, Reward = 1.0
# Step 275: State = [-0.441 -0.53   0.009  0.715], Action = 1, Reward = 1.0
# Step 276: State = [-0.452 -0.335  0.024  0.425], Action = 1, Reward = 1.0
# Step 277: State = [-0.458 -0.14   0.032  0.14 ], Action = 1, Reward = 1.0
# Step 278: State = [-0.461  0.055  0.035 -0.142], Action = 1, Reward = 1.0
# Step 279: State = [-0.46   0.249  0.032 -0.424], Action = 1, Reward = 1.0
# Step 280: State = [-0.455  0.444  0.024 -0.706], Action = 1, Reward = 1.0
# Step 281: State = [-0.446  0.639  0.01  -0.991], Action = 0, Reward = 1.0
# Step 282: State = [-0.434  0.443 -0.01  -0.695], Action = 0, Reward = 1.0
# Step 283: State = [-0.425  0.248 -0.024 -0.406], Action = 0, Reward = 1.0
# Step 284: State = [-0.42   0.054 -0.032 -0.121], Action = 0, Reward = 1.0
# Step 285: State = [-0.419 -0.141 -0.035  0.161], Action = 0, Reward = 1.0
# Step 286: State = [-0.421 -0.336 -0.031  0.443], Action = 0, Reward = 1.0
# Step 287: State = [-0.428 -0.53  -0.023  0.725], Action = 0, Reward = 1.0
# Step 288: State = [-0.439 -0.725 -0.008  1.011], Action = 1, Reward = 1.0
# Step 289: State = [-0.453 -0.53   0.012  0.716], Action = 1, Reward = 1.0
# Step 290: State = [-0.464 -0.335  0.026  0.427], Action = 1, Reward = 1.0
# Step 291: State = [-0.471 -0.14   0.035  0.143], Action = 1, Reward = 1.0
# Step 292: State = [-0.473  0.054  0.038 -0.139], Action = 1, Reward = 1.0
# Step 293: State = [-0.472  0.249  0.035 -0.419], Action = 1, Reward = 1.0
# Step 294: State = [-0.467  0.444  0.027 -0.701], Action = 1, Reward = 1.0
# Step 295: State = [-0.458  0.638  0.013 -0.985], Action = 0, Reward = 1.0
# Step 296: State = [-0.446  0.443 -0.007 -0.688], Action = 0, Reward = 1.0
# Step 297: State = [-0.437  0.248 -0.021 -0.398], Action = 0, Reward = 1.0
# Step 298: State = [-0.432  0.053 -0.029 -0.112], Action = 0, Reward = 1.0
# Step 299: State = [-0.431 -0.142 -0.031  0.172], Action = 0, Reward = 1.0
# Step 300: State = [-0.434 -0.336 -0.028  0.454], Action = 0, Reward = 1.0
# Step 301: State = [-0.44  -0.531 -0.018  0.738], Action = 0, Reward = 1.0
# Step 302: State = [-0.451 -0.726 -0.004  1.025], Action = 1, Reward = 1.0
# Step 303: State = [-0.466 -0.531  0.017  0.731], Action = 1, Reward = 1.0
# Step 304: State = [-0.476 -0.336  0.031  0.444], Action = 1, Reward = 1.0
# Step 305: State = [-0.483 -0.141  0.04   0.161], Action = 1, Reward = 1.0
# Step 306: State = [-0.486  0.053  0.044 -0.118], Action = 1, Reward = 1.0
# Step 307: State = [-0.485  0.248  0.041 -0.397], Action = 1, Reward = 1.0
# Step 308: State = [-0.48   0.442  0.033 -0.676], Action = 1, Reward = 1.0
# Step 309: State = [-0.471  0.637  0.02  -0.958], Action = 0, Reward = 1.0
# Step 310: State = [-0.458  0.442  0.001 -0.66 ], Action = 0, Reward = 1.0
# Step 311: State = [-0.449  0.247 -0.013 -0.367], Action = 0, Reward = 1.0
# Step 312: State = [-0.444  0.052 -0.02  -0.078], Action = 0, Reward = 1.0
# Step 313: State = [-0.443 -0.143 -0.022  0.208], Action = 0, Reward = 1.0
# Step 314: State = [-0.446 -0.338 -0.017  0.494], Action = 0, Reward = 1.0
# Step 315: State = [-0.453 -0.533 -0.008  0.781], Action = 1, Reward = 1.0
# Step 316: State = [-0.464 -0.338  0.008  0.486], Action = 1, Reward = 1.0
# Step 317: State = [-0.47  -0.143  0.018  0.196], Action = 1, Reward = 1.0
# Step 318: State = [-0.473  0.052  0.022 -0.091], Action = 1, Reward = 1.0
# Step 319: State = [-0.472  0.247  0.02  -0.377], Action = 1, Reward = 1.0
# Step 320: State = [-0.467  0.442  0.012 -0.663], Action = 0, Reward = 1.0
# Step 321: State = [-0.458  0.247 -0.001 -0.367], Action = 0, Reward = 1.0
# Step 322: State = [-0.453  0.051 -0.008 -0.074], Action = 0, Reward = 1.0
# Step 323: State = [-0.452 -0.144 -0.01   0.216], Action = 0, Reward = 1.0
# Step 324: State = [-0.455 -0.339 -0.005  0.506], Action = 1, Reward = 1.0
# Step 325: State = [-0.462 -0.143  0.005  0.211], Action = 1, Reward = 1.0
# Step 326: State = [-0.465  0.052  0.009 -0.08 ], Action = 1, Reward = 1.0
# Step 327: State = [-0.464  0.247  0.007 -0.37 ], Action = 0, Reward = 1.0
# Step 328: State = [-0.459  0.051 -0.    -0.075], Action = 0, Reward = 1.0
# Step 329: State = [-0.458 -0.144 -0.002  0.218], Action = 0, Reward = 1.0
# Step 330: State = [-0.461 -0.339  0.003  0.51 ], Action = 1, Reward = 1.0
# Step 331: State = [-0.468 -0.144  0.013  0.218], Action = 1, Reward = 1.0
# Step 332: State = [-0.47   0.051  0.017 -0.07 ], Action = 1, Reward = 1.0
# Step 333: State = [-0.469  0.246  0.016 -0.357], Action = 1, Reward = 1.0
# Step 334: State = [-0.464  0.441  0.009 -0.645], Action = 0, Reward = 1.0
# Step 335: State = [-0.456  0.246 -0.004 -0.35 ], Action = 0, Reward = 1.0
# Step 336: State = [-0.451  0.051 -0.011 -0.058], Action = 0, Reward = 1.0
# Step 337: State = [-0.45  -0.144 -0.012  0.231], Action = 0, Reward = 1.0
# Step 338: State = [-0.453 -0.339 -0.008  0.52 ], Action = 1, Reward = 1.0
# Step 339: State = [-0.459 -0.144  0.003  0.225], Action = 1, Reward = 1.0
# Step 340: State = [-0.462  0.051  0.007 -0.067], Action = 1, Reward = 1.0
# Step 341: State = [-0.461  0.246  0.006 -0.357], Action = 0, Reward = 1.0
# Step 342: State = [-0.456  0.051 -0.001 -0.063], Action = 0, Reward = 1.0
# Step 343: State = [-0.455 -0.144 -0.002  0.229], Action = 0, Reward = 1.0
# Step 344: State = [-0.458 -0.339  0.002  0.521], Action = 1, Reward = 1.0
# Step 345: State = [-0.465 -0.144  0.013  0.229], Action = 1, Reward = 1.0
# Step 346: State = [-0.468  0.051  0.017 -0.059], Action = 1, Reward = 1.0
# Step 347: State = [-0.467  0.246  0.016 -0.347], Action = 1, Reward = 1.0
# Step 348: State = [-0.462  0.441  0.009 -0.634], Action = 0, Reward = 1.0
# Step 349: State = [-0.453  0.245 -0.004 -0.339], Action = 0, Reward = 1.0
# Step 350: State = [-0.448  0.05  -0.01  -0.047], Action = 0, Reward = 1.0
# Step 351: State = [-0.447 -0.145 -0.011  0.242], Action = 0, Reward = 1.0
# Step 352: State = [-0.45  -0.34  -0.007  0.531], Action = 1, Reward = 1.0
# Step 353: State = [-0.457 -0.144  0.004  0.237], Action = 1, Reward = 1.0
# Step 354: State = [-0.46   0.051  0.009 -0.055], Action = 1, Reward = 1.0
# Step 355: State = [-0.459  0.246  0.008 -0.345], Action = 0, Reward = 1.0
# Step 356: State = [-0.454  0.05   0.001 -0.05 ], Action = 0, Reward = 1.0
# Step 357: State = [-0.453 -0.145 -0.     0.243], Action = 1, Reward = 1.0
# Step 358: State = [-0.456  0.05   0.005 -0.049], Action = 1, Reward = 1.0
# Step 359: State = [-0.455  0.245  0.004 -0.34 ], Action = 0, Reward = 1.0
# Step 360: State = [-0.45   0.05  -0.003 -0.047], Action = 0, Reward = 1.0
# Step 361: State = [-0.449 -0.145 -0.004  0.245], Action = 0, Reward = 1.0
# Step 362: State = [-0.452 -0.34   0.001  0.537], Action = 1, Reward = 1.0
# Step 363: State = [-0.458 -0.145  0.012  0.244], Action = 1, Reward = 1.0
# Step 364: State = [-0.461  0.05   0.017 -0.045], Action = 1, Reward = 1.0
# Step 365: State = [-0.46   0.245  0.016 -0.332], Action = 1, Reward = 1.0
# Step 366: State = [-0.455  0.44   0.009 -0.62 ], Action = 0, Reward = 1.0
# Step 367: State = [-0.447  0.245 -0.003 -0.324], Action = 0, Reward = 1.0
# Step 368: State = [-0.442  0.05  -0.01  -0.033], Action = 0, Reward = 1.0
# Step 369: State = [-0.441 -0.145 -0.011  0.257], Action = 0, Reward = 1.0
# Step 370: State = [-0.444 -0.34  -0.005  0.546], Action = 1, Reward = 1.0
# Step 371: State = [-0.451 -0.145  0.005  0.252], Action = 1, Reward = 1.0
# Step 372: State = [-0.453  0.05   0.011 -0.039], Action = 1, Reward = 1.0
# Step 373: State = [-0.452  0.245  0.01  -0.329], Action = 1, Reward = 1.0
# Step 374: State = [-0.448  0.44   0.003 -0.618], Action = 0, Reward = 1.0
# Step 375: State = [-0.439  0.245 -0.009 -0.325], Action = 0, Reward = 1.0
# Step 376: State = [-0.434  0.05  -0.016 -0.035], Action = 0, Reward = 1.0
# Step 377: State = [-0.433 -0.145 -0.016  0.253], Action = 0, Reward = 1.0
# Step 378: State = [-0.436 -0.34  -0.011  0.54 ], Action = 0, Reward = 1.0
# Step 379: State = [-0.443 -0.535 -0.001  0.829], Action = 1, Reward = 1.0
# Step 380: State = [-0.453 -0.34   0.016  0.537], Action = 1, Reward = 1.0
# Step 381: State = [-0.46  -0.145  0.027  0.249], Action = 1, Reward = 1.0
# Step 382: State = [-0.463  0.05   0.032 -0.035], Action = 1, Reward = 1.0
# Step 383: State = [-0.462  0.244  0.031 -0.318], Action = 1, Reward = 1.0
# Step 384: State = [-0.457  0.439  0.025 -0.6  ], Action = 1, Reward = 1.0
# Step 385: State = [-0.448  0.634  0.013 -0.885], Action = 0, Reward = 1.0
# Step 386: State = [-0.436  0.438 -0.005 -0.588], Action = 0, Reward = 1.0
# Step 387: State = [-0.427  0.243 -0.017 -0.297], Action = 0, Reward = 1.0
# Step 388: State = [-0.422  0.049 -0.023 -0.01 ], Action = 0, Reward = 1.0
# Step 389: State = [-0.421 -0.146 -0.023  0.275], Action = 0, Reward = 1.0
# Step 390: State = [-0.424 -0.341 -0.017  0.561], Action = 0, Reward = 1.0
# Step 391: State = [-0.431 -0.536 -0.006  0.848], Action = 1, Reward = 1.0
# Step 392: State = [-0.441 -0.341  0.011  0.553], Action = 1, Reward = 1.0
# Step 393: State = [-0.448 -0.146  0.022  0.264], Action = 1, Reward = 1.0
# Step 394: State = [-0.451  0.049  0.027 -0.022], Action = 1, Reward = 1.0
# Step 395: State = [-0.45   0.244  0.027 -0.306], Action = 1, Reward = 1.0
# Step 396: State = [-0.445  0.439  0.021 -0.59 ], Action = 1, Reward = 1.0
# Step 397: State = [-0.437  0.633  0.009 -0.876], Action = 0, Reward = 1.0
# Step 398: State = [-0.424  0.438 -0.009 -0.58 ], Action = 0, Reward = 1.0
# Step 399: State = [-0.415  0.243 -0.02  -0.291], Action = 0, Reward = 1.0
# Step 400: State = [-0.41   0.048 -0.026 -0.004], Action = 0, Reward = 1.0
# Step 401: State = [-0.409 -0.146 -0.026  0.28 ], Action = 0, Reward = 1.0
# Step 402: State = [-0.412 -0.341 -0.021  0.564], Action = 0, Reward = 1.0
# Step 403: State = [-0.419 -0.536 -0.009  0.85 ], Action = 1, Reward = 1.0
# Step 404: State = [-0.43  -0.341  0.008  0.555], Action = 1, Reward = 1.0
# Step 405: State = [-0.437 -0.146  0.019  0.264], Action = 1, Reward = 1.0
# Step 406: State = [-0.44   0.049  0.024 -0.022], Action = 1, Reward = 1.0
# Step 407: State = [-0.439  0.244  0.024 -0.307], Action = 1, Reward = 1.0
# Step 408: State = [-0.434  0.439  0.017 -0.592], Action = 1, Reward = 1.0
# Step 409: State = [-0.425  0.634  0.006 -0.88 ], Action = 0, Reward = 1.0
# Step 410: State = [-0.412  0.438 -0.012 -0.585], Action = 0, Reward = 1.0
# Step 411: State = [-0.403  0.243 -0.024 -0.296], Action = 0, Reward = 1.0
# Step 412: State = [-0.399  0.049 -0.03  -0.011], Action = 0, Reward = 1.0
# Step 413: State = [-0.398 -0.146 -0.03   0.272], Action = 0, Reward = 1.0
# Step 414: State = [-0.401 -0.341 -0.024  0.555], Action = 0, Reward = 1.0
# Step 415: State = [-0.407 -0.536 -0.013  0.84 ], Action = 1, Reward = 1.0
# Step 416: State = [-0.418 -0.34   0.004  0.543], Action = 1, Reward = 1.0
# Step 417: State = [-0.425 -0.145  0.014  0.252], Action = 1, Reward = 1.0
# Step 418: State = [-0.428  0.05   0.019 -0.036], Action = 1, Reward = 1.0
# Step 419: State = [-0.427  0.245  0.019 -0.323], Action = 1, Reward = 1.0
# Step 420: State = [-0.422  0.439  0.012 -0.61 ], Action = 1, Reward = 1.0
# Step 421: State = [-0.413  0.634  0.    -0.898], Action = 0, Reward = 1.0
# Step 422: State = [-0.4    0.439 -0.018 -0.606], Action = 0, Reward = 1.0
# Step 423: State = [-0.392  0.244 -0.03  -0.319], Action = 0, Reward = 1.0
# Step 424: State = [-0.387  0.05  -0.036 -0.036], Action = 0, Reward = 1.0
# Step 425: State = [-0.386 -0.145 -0.037  0.245], Action = 0, Reward = 1.0
# Step 426: State = [-0.389 -0.339 -0.032  0.526], Action = 0, Reward = 1.0
# Step 427: State = [-0.395 -0.534 -0.022  0.808], Action = 1, Reward = 1.0
# Step 428: State = [-0.406 -0.339 -0.006  0.509], Action = 1, Reward = 1.0
# Step 429: State = [-0.413 -0.143  0.005  0.215], Action = 1, Reward = 1.0
# Step 430: State = [-0.416  0.052  0.009 -0.077], Action = 1, Reward = 1.0
# Step 431: State = [-0.415  0.247  0.007 -0.366], Action = 1, Reward = 1.0
# Step 432: State = [-0.41   0.442  0.    -0.657], Action = 0, Reward = 1.0
# Step 433: State = [-0.401  0.246 -0.013 -0.364], Action = 0, Reward = 1.0
# Step 434: State = [-0.396  0.052 -0.02  -0.076], Action = 0, Reward = 1.0
# Step 435: State = [-0.395 -0.143 -0.022  0.211], Action = 0, Reward = 1.0
# Step 436: State = [-0.398 -0.338 -0.018  0.496], Action = 0, Reward = 1.0
# Step 437: State = [-0.405 -0.533 -0.008  0.783], Action = 1, Reward = 1.0
# Step 438: State = [-0.415 -0.338  0.008  0.488], Action = 1, Reward = 1.0
# Step 439: State = [-0.422 -0.143  0.018  0.198], Action = 1, Reward = 1.0
# Step 440: State = [-0.425  0.052  0.022 -0.089], Action = 1, Reward = 1.0
# Step 441: State = [-0.424  0.247  0.02  -0.375], Action = 1, Reward = 1.0
# Step 442: State = [-0.419  0.442  0.012 -0.661], Action = 0, Reward = 1.0
# Step 443: State = [-0.41   0.246 -0.001 -0.364], Action = 0, Reward = 1.0
# Step 444: State = [-0.405  0.051 -0.008 -0.072], Action = 0, Reward = 1.0
# Step 445: State = [-0.404 -0.144 -0.01   0.218], Action = 0, Reward = 1.0
# Step 446: State = [-0.407 -0.339 -0.005  0.508], Action = 1, Reward = 1.0
# Step 447: State = [-0.414 -0.143  0.005  0.213], Action = 1, Reward = 1.0
# Step 448: State = [-0.417  0.052  0.009 -0.078], Action = 1, Reward = 1.0
# Step 449: State = [-0.416  0.247  0.008 -0.367], Action = 1, Reward = 1.0
# Step 450: State = [-0.411  0.442  0.    -0.658], Action = 0, Reward = 1.0
# Step 451: State = [-0.402  0.246 -0.013 -0.365], Action = 0, Reward = 1.0
# Step 452: State = [-0.397  0.052 -0.02  -0.076], Action = 0, Reward = 1.0
# Step 453: State = [-0.396 -0.143 -0.022  0.21 ], Action = 0, Reward = 1.0
# Step 454: State = [-0.399 -0.338 -0.017  0.496], Action = 0, Reward = 1.0
# Step 455: State = [-0.405 -0.533 -0.007  0.783], Action = 1, Reward = 1.0
# Step 456: State = [-0.416 -0.338  0.008  0.488], Action = 1, Reward = 1.0
# Step 457: State = [-0.423 -0.143  0.018  0.198], Action = 1, Reward = 1.0
# Step 458: State = [-0.426  0.052  0.022 -0.089], Action = 1, Reward = 1.0
# Step 459: State = [-0.425  0.247  0.02  -0.375], Action = 1, Reward = 1.0
# Step 460: State = [-0.42   0.442  0.013 -0.661], Action = 0, Reward = 1.0
# Step 461: State = [-0.411  0.246 -0.001 -0.364], Action = 0, Reward = 1.0
# Step 462: State = [-0.406  0.051 -0.008 -0.072], Action = 0, Reward = 1.0
# Step 463: State = [-0.405 -0.144 -0.009  0.218], Action = 0, Reward = 1.0
# Step 464: State = [-0.408 -0.339 -0.005  0.508], Action = 1, Reward = 1.0
# Step 465: State = [-0.415 -0.143  0.005  0.214], Action = 1, Reward = 1.0
# Step 466: State = [-0.418  0.052  0.009 -0.077], Action = 1, Reward = 1.0
# Step 467: State = [-0.416  0.247  0.008 -0.367], Action = 1, Reward = 1.0
# Step 468: State = [-0.412  0.442  0.001 -0.657], Action = 0, Reward = 1.0
# Step 469: State = [-0.403  0.246 -0.013 -0.364], Action = 0, Reward = 1.0
# Step 470: State = [-0.398  0.052 -0.02  -0.076], Action = 0, Reward = 1.0
# Step 471: State = [-0.397 -0.143 -0.021  0.211], Action = 0, Reward = 1.0
# Step 472: State = [-0.4   -0.338 -0.017  0.496], Action = 0, Reward = 1.0
# Step 473: State = [-0.406 -0.533 -0.007  0.784], Action = 1, Reward = 1.0
# Step 474: State = [-0.417 -0.338  0.008  0.489], Action = 1, Reward = 1.0
# Step 475: State = [-0.424 -0.143  0.018  0.199], Action = 1, Reward = 1.0
# Step 476: State = [-0.427  0.052  0.022 -0.088], Action = 1, Reward = 1.0
# Step 477: State = [-0.426  0.247  0.02  -0.374], Action = 1, Reward = 1.0
# Step 478: State = [-0.421  0.442  0.013 -0.66 ], Action = 0, Reward = 1.0
# Step 479: State = [-0.412  0.246 -0.    -0.363], Action = 0, Reward = 1.0
# Step 480: State = [-0.407  0.051 -0.008 -0.071], Action = 0, Reward = 1.0
# Step 481: State = [-0.406 -0.144 -0.009  0.22 ], Action = 0, Reward = 1.0
# Step 482: State = [-0.409 -0.339 -0.005  0.51 ], Action = 1, Reward = 1.0
# Step 483: State = [-0.416 -0.144  0.006  0.215], Action = 1, Reward = 1.0
# Step 484: State = [-0.418  0.052  0.01  -0.075], Action = 1, Reward = 1.0
# Step 485: State = [-0.417  0.246  0.008 -0.365], Action = 1, Reward = 1.0
# Step 486: State = [-0.412  0.441  0.001 -0.655], Action = 0, Reward = 1.0
# Step 487: State = [-0.404  0.246 -0.012 -0.362], Action = 0, Reward = 1.0
# Step 488: State = [-0.399  0.051 -0.019 -0.073], Action = 0, Reward = 1.0
# Step 489: State = [-0.398 -0.143 -0.021  0.214], Action = 0, Reward = 1.0
# Step 490: State = [-0.401 -0.338 -0.016  0.5  ], Action = 0, Reward = 1.0
# Step 491: State = [-0.407 -0.533 -0.006  0.787], Action = 1, Reward = 1.0
# Step 492: State = [-0.418 -0.338  0.009  0.492], Action = 1, Reward = 1.0
# Step 493: State = [-0.425 -0.143  0.019  0.203], Action = 1, Reward = 1.0
# Step 494: State = [-0.428  0.052  0.023 -0.084], Action = 1, Reward = 1.0
# Step 495: State = [-0.427  0.247  0.022 -0.369], Action = 1, Reward = 1.0
# Step 496: State = [-0.422  0.441  0.014 -0.655], Action = 1, Reward = 1.0
# Step 497: State = [-0.413  0.636  0.001 -0.943], Action = 0, Reward = 1.0
# Step 498: State = [-0.4    0.441 -0.018 -0.65 ], Action = 0, Reward = 1.0
# Step 499: State = [-0.391  0.246 -0.031 -0.363], Action = 0, Reward = 1.0
#
# Greedy Episode Total Reward: 500.0
